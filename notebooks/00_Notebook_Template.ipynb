# %% [markdown]
# <p align="center">
#     <img src="../assets/banner.png" width="100%">
# </p>
#
# <h1 align="center">🏏 Python Lab Portfolio</h1>
#
# <h2 align="center">Cricket Analytics Edition</h2>
#
# ---
#
# # Experiment X
#
# ## Experiment Title
#
# ---
#
# ## 👨‍🎓 Student Information
#
# | Field | Details |
# |:------|:--------|
# | **Name** | Maanav Singh |
# | **SAP ID** | 590039016 |
# | **Course** | Python Programming Lab |
# | **University** | UPES |
# | **Academic Year** | 2026–27 |
#
# ---
#
# ## 📋 Experiment Information
#
# | Field | Details |
# |:------|:--------|
# | **Experiment No.** | X |
# | **Topic** | Replace with topic |
# | **Programming Language** | Python |
# | **IDE** | Visual Studio Code |
# | **Theme** | Cricket Analytics |
#
# ---

# %% [markdown]
# # 🎯 Aim
#
# Write the objective of the experiment.

# %% [markdown]
# # 📘 Theory
#
# Explain the concepts used in this experiment.
#
# Include:
#
# - Definition
# - Working Principle
# - Importance
# - Real-world Applications

# %% [markdown]
# # 🧠 Learning Outcomes
#
# After completing this experiment, you will be able to:
#
# - Understand ...
# - Implement ...
# - Analyse ...
# - Apply ...

# %% [markdown]
# # 💻 Experiment Implementation

# %% [markdown]
# ## Program 1
#
# ### Problem Statement
#
# Write a Python program to...
#
# ### Code

# %% [markdown]
# # Write your Python code here

# %% [markdown]
# ### Explanation
#
# Explain the logic of the program.

# %% [markdown]
# ### Output

# %%
# Run the above program to display the output.

# %% [markdown]
# # 🏏 Cricket Analytics Extension
#
# Use the concepts learned in this experiment to create a small cricket-related application or example.

# %%
# Cricket Analytics Example

# %% [markdown]
# # 💡 Reflection
#
# ### What I Learned
#
# - ...
# - ...
# - ...
#
# ### Challenges Faced
#
# - ...
#
# ### Connection to the Mini Project
#
# Explain how this experiment will help while developing the Cricket Analytics Dashboard.

# %% [markdown]
# # 📌 Conclusion
#
# Summarize the experiment.
#
# Mention:
#
# - Objective achieved
# - Python concepts learned
# - Practical applications
# - Relevance to the Cricket Analytics Dashboard
