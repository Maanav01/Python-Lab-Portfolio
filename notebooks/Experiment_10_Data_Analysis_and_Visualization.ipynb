# %% [markdown]
# <p align="center">
#     <img src="../assets/banner.png" width="100%">
# </p>
#
# <h1 align="center">🏏 Python Lab Portfolio</h1>
#
# <h2 align="center">Cricket Analytics Edition</h2>
#
# ---
#
# # Experiment 10
#
# ## Data Analysis and Visualization
#
# ---
#
# ## 👨‍🎓 Student Information
#
# | Field | Details |
# |:------|:--------|
# | **Name** | Maanav Singh |
# | **SAP ID** | 590039016 |
# | **Course** | Python Programming Lab |
# | **University** | UPES |
# | **Academic Year** | 2026–27 |
#
# ---
#
# ## 📋 Experiment Information
#
# | Field | Details |
# |:------|:--------|
# | **Experiment No.** | 10 |
# | **Topic** | Data Analysis and Visualization |
# | **Programming Language** | Python |
# | **IDE** | Visual Studio Code |
# | **Theme** | Cricket Analytics |
#
# ---

# %% [markdown]
# # 🎯 Aim
#
# To understand data analysis and visualization in Python using NumPy, Pandas, and Matplotlib by performing numerical computations, data manipulation, and graphical representation of datasets.

# %% [markdown]
# # 📘 Theory
#
# Data analysis involves collecting, processing, and interpreting data to extract meaningful insights.
#
# Python provides powerful libraries for this purpose:
#
# - **NumPy** – Efficient numerical computations and multidimensional arrays.
# - **Pandas** – Data manipulation and analysis using Series and DataFrames.
# - **Matplotlib** – Data visualization through charts and graphs.
#
# These libraries are extensively used in data science, machine learning, business analytics, and scientific computing.

# %% [markdown]
# # 🧠 Learning Outcomes
#
# After completing this experiment, I was able to:
#
# - Create and manipulate NumPy arrays.
# - Perform matrix operations.
# - Analyse datasets using Pandas.
# - Handle missing values in DataFrames.
# - Create different types of visualizations using Matplotlib.

# %% [markdown]
# ## 💻 Experiment Implementation

# %% [markdown]
# ## Question 1
# ### Problem Statement
#
# Create a NumPy array and find the sum of all elements.

# %%
import numpy as np

arr = np.array([12, 25, 7, 30, 16])

print("Array:", arr)
print("Sum of all elements:", np.sum(arr))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import numpy as np
#       2
#       3 arr = np.array([12, 25, 7, 30, 16])
#       4
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\maanav\AppData\Local\Programs\Python\Python314\python.exe
